# %%
from pyspark.sql.functions import col

# %%
bikes_account_key = dbutils.secrets.get(scope = "bikes-scope", key = "account-key")
spark.conf.set(
    "fs.azure.account.key.adlsbikestoreinterns.blob.core.windows.net",
    bikes_account_key
)
spark.conf.set("fs.azure.account.key.adlsbikestoreinterns.blob.core.windows.net", "2A7Fbw9UkJ7R03r/x+uw6/JNClb4b73dpL+KGsIVfAOpJfRVBjH1rjMC2xLTj4uVCR/j8qgXfabp+AStWjlnNg==")
dbutils.secrets.listScopes()
dbutils.secrets.list(scope = "bikes-scope")
bikes_account_key = dbutils.secrets.get(scope = "bikes-scope", key = "account-key")
spark.conf.set(
    "fs.azure.account.key.adlsbikestoreinterns.blob.core.windows.net",
    bikes_account_key
)

# %%
stage1_source_path = f"wasbs://dlbikestorestage1@adlsbikestoreinterns.blob.core.windows.net/mostafa"
stage2_source_path = f"wasbs://dlbikestorestage2@adlsbikestoreinterns.blob.core.windows.net/mostafa"
infomart_path = f"wasbs://dlbikestoreinfomart@adlsbikestoreinterns.blob.core.windows.net/mostafa/order_fact"
order_df = spark.read.format('delta').load(stage1_source_path + '/order')
order_items_df = spark.read.format('delta').load(stage1_source_path + '/order_items')
date_lookup_df = spark.read.format('delta').load(stage2_source_path + '/date_lookup')

# %%
order_fact_df = order_df.join(order_items_df, on="order_id", how="full_outer")
display(order_fact_df)

# %%
display(date_lookup_df)

# %%
order_df = order_df.drop("timestamp", "extraction_id")
order_fact_df = order_df.join(order_items_df, order_df.order_id == order_items_df.order_id, "left").drop(order_items_df.order_id)
order_fact_df = order_fact_df.drop('item_id', 'source')
display(order_fact_df)

# %%
# Join on ordered_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("date", "order_date")
             .withColumnRenamed("date_id", "order_date_id"),
             "order_date", "left")

# Join on required_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("order_date", "required_date")
             .withColumnRenamed("order_date_id", "required_date_id")
             .withColumnRenamed("date", "required_date")
             .withColumnRenamed("date_id", "required_date_id"),
             "required_date", "left")

# Join on shipped_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("order_date", "shipped_date")
             .withColumnRenamed("order_date_id", "shipped_date_id")
             .withColumnRenamed("date", "shipped_date")
             .withColumnRenamed("date_id", "shipped_date_id"),
             "shipped_date", "left")
order_fact_df = order_fact_df.drop("order_date", "required_date", "shipped_date")

display(order_fact_df)

# %%
order_fact = order_fact_df

# %%
display(order_fact)

# %%
order_df = order_df.drop("timestamp", "extraction_id")
order_fact_df = order_df.join(order_items_df, order_df.order_id == order_items_df.order_id, "left").drop(order_items_df.order_id)
order_fact_df = order_fact_df.drop('item_id', 'source')

# Join on ordered_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("date", "order_date")
             .withColumnRenamed("date_id", "order_date_id"),
             "order_date", "left")

# Join on required_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("order_date", "required_date")
             .withColumnRenamed("order_date_id", "required_date_id")
             .withColumnRenamed("date", "required_date")
             .withColumnRenamed("date_id", "required_date_id"),
             "required_date", "left")

# Join on shipped_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("order_date", "shipped_date")
             .withColumnRenamed("order_date_id", "shipped_date_id")
             .withColumnRenamed("date", "shipped_date")
             .withColumnRenamed("date_id", "shipped_date_id"),
             "shipped_date", "left")
order_fact_df = order_fact_df.drop("order_date", "required_date", "shipped_date")

display(order_fact_df)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
# Join on ordered_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("date", "order_date")
             .withColumnRenamed("date_id", "order_date_id"),
             "order_date", "left")

# Join on required_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("order_date", "required_date")
             .withColumnRenamed("order_date_id", "required_date_id")
             .withColumnRenamed("date", "required_date")
             .withColumnRenamed("date_id", "required_date_id"),
             "required_date", "left")

# Join on shipped_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("order_date", "shipped_date")
             .withColumnRenamed("order_date_id", "shipped_date_id")
             .withColumnRenamed("date", "shipped_date")
             .withColumnRenamed("date_id", "shipped_date_id"),
             "shipped_date", "left")
order_fact_df = order_fact_df.drop("order_date", "required_date", "shipped_date")

display(order_fact_df)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
display (order_fact_df)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
# Remove duplicate columns
order_fact_df = order_fact_df.toDF(*[f"{col}_{i}" if col in order_fact_df.columns[:i] else col 
                                     for i, col in enumerate(order_fact_df.columns)])

display(order_fact_df)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
# Write the DataFrame to Delta format
order_fact_df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(infomart_path)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
order_df = spark.read.format('delta').load(stage1_source_path + '/order')
order_items_df = spark.read.format('delta').load(stage1_source_path + '/order_items')
date_lookup_df = spark.read.format('delta').load(stage2_source_path + '/date_lookup')
stores = spark.read.format('delta').load(f"wasbs://dlbikestoreinfomart@adlsbikestoreinterns.blob.core.windows.net/mostafa/store_dim")
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
order_df = order_df.drop("timestamp", "extraction_id")
order_fact_df = order_df.join(order_items_df, order_df.order_id == order_items_df.order_id, "left").drop(order_items_df.order_id)
order_fact_df = order_fact_df.drop('item_id', 'source')
display(order_fact_df)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
# Join on ordered_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("date", "order_date")
             .withColumnRenamed("date_id", "order_date_id"),
             "order_date", "left")

# Join on required_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("order_date", "required_date")
             .withColumnRenamed("order_date_id", "required_date_id")
             .withColumnRenamed("date", "required_date")
             .withColumnRenamed("date_id", "required_date_id"),
             "required_date", "left")

# Join on shipped_date
order_fact_df = order_fact_df.join(date_lookup_df.withColumnRenamed("order_date", "shipped_date")
             .withColumnRenamed("order_date_id", "shipped_date_id")
             .withColumnRenamed("date", "shipped_date")
             .withColumnRenamed("date_id", "shipped_date_id"),
             "shipped_date", "left")
order_fact_df = order_fact_df.drop("order_date", "required_date", "shipped_date")

display(order_fact_df)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
import pyspark.sql.functions as F
displayedDF = order_fact_df.alias('a').join(stores.alias('b'), on= F.col('a.store_id') == F.col('b.store_id'), how= 'inner').select(['a.*','b.store_name'])

display(displayedDF)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
order_fact_df.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(infomart_path)
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...

# %%
order_fact.write.format("delta").mode("overwrite").option("overwriteSchema", "true").save(f'{infomart_path}/order_fact/')
# Out:
# com.databricks.backend.common.rpc.CommandSkippedException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:138)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:133)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:133)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:727)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:445)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:445)
# 	at com.databricks.spark.chauffeur.ChauffeurState.cancelExecution(ChauffeurState.scala:1268)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:985)
# ...
